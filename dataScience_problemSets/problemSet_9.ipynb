# %%
"""
Create 3D surface plot of a function z=x2−y2 . Add axes labels and color bar.
"""
# %matplotlib inline
import re, seaborn as sb
import matplotlib.pyplot as pyplt
from matplotlib import cm
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.colors import ListedColormap

# %%
#define function
def FUNC_Z(x, y):
    return (x**2 - y**2)

# Create Grid
sb.set_style('darkgrid')

X_VAL = np.linspace(-100, 100, 10)
Y_VAL = np.linspace(-100, 100, 10)

X1, Y1 = np.meshgrid(X_VAL, Y_VAL)

Z1 = FUNC_Z(X1, Y1)

# Create graph
norm = pyplt.Normalize(Z1.min(), Z1.max())
colors = cm.viridis(norm(Z1))
rcount, ccount, _ = colors.shape

#Graph 1
axes = pyplt.axes(projection='3d')
axes.plot_surface(X1, Y1, Z1)

surf = axes.plot_surface(X1, Y1, Z1, rcount=rcount, ccount=ccount,
                       facecolors=colors, shade=True)
surf.set_facecolor((0,0,0,0))

pyplt.show()

#Graph 2
axes = pyplt.axes(projection='3d')
axes.plot_wireframe(X1, Y1, Z1)

surf = axes.plot_surface(X1, Y1, Z1, rcount=rcount, ccount=ccount,
                       facecolors=colors, shade=True)
surf.set_facecolor((0,0,0,0))

pyplt.show()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[16], line 32
#      29 img.set_visible(False)
#      31 pyplt.show()
# ---> 32 pyplt.colorbar(orientation="vertical")
#      34 #Graph 2
#      35 axes = pyplt.axes(projection='3d')
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\matplotlib\pyplot.py:2061, in colorbar(mappable, cax, ax, **kwargs)
#    2059     mappable = gci()
#    2060     if mappable is None:
# -> 2061         raise RuntimeError('No mappable was found to use for colorbar '
#    2062                            'creation. First define a mappable such as '
#    2063                            'an image (with imshow) or a contour set ('
#    2064                            'with contourf).')
#    2065 ret = gcf().colorbar(mappable, cax=cax, ax=ax, **kwargs)
# ...
